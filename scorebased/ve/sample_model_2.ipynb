# %%
import torch
from torchvision import transforms
from score_models import ScoreModel, EnergyModel, NCSNpp, MLP, DDPM
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision.utils as vutils
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
import os
from PIL import Image

# %%
score = ScoreModel(seed = 0, checkpoints_directory="/home/mjybarth/scratch/cats_3_checkpoints")
# Out:
# Loaded checkpoint 0 of cats_3_checkpoints
# Using the Variance Exploding SDE

# %%
sample = score.sample(shape = [8, 1, 64, 64], steps = 1000)
# Out:
# Sampling from the prior | t = 0.0 | sigma = 1.0e-02| scale ~ 4.6e-01: 100%|██████████| 1000/1000 [00:27<00:00, 36.54it/s]

# %%
plt.imshow(sample.to("cpu").numpy()[5, 0], cmap = "gray")
plt.show()

# %%
sample = score.sample(shape = [8, 1, 64, 64], steps = 1000)
# Out:
# Sampling from the prior | t = 0.0 | sigma = 1.0e-02| scale ~ 4.6e-01: 100%|██████████| 1000/1000 [00:29<00:00, 34.11it/s]

# %%
plt.imshow(sample.to("cpu").numpy()[5, 0], cmap = "gray")
plt.show()

# %%
sample2 = score.sample(shape = [8, 1, 64, 64], steps = 1000)
# Out:
# Sampling from the prior | t = 0.0 | sigma = 1.0e-02| scale ~ 4.2e-01: 100%|██████████| 1000/1000 [00:27<00:00, 35.79it/s]

# %%
plt.imshow(sample2.to("cpu").numpy()[5, 0], cmap = "gray")
plt.show()

# %%
sample3 = score.sample(shape = [8, 1, 64, 64], steps = 1000)
# Out:
# Sampling from the prior | t = 0.0 | sigma = 1.0e-02| scale ~ 5.4e-01: 100%|██████████| 1000/1000 [00:27<00:00, 35.79it/s]

# %%
plt.imshow(sample3.to("cpu").numpy()[5, 0], cmap = "gray")
plt.show()

# %%
sample4 = score.sample(shape = [8, 1, 64, 64], steps = 1000)
# Out:
# Sampling from the prior | t = 0.0 | sigma = 1.0e-02| scale ~ 5.0e-01: 100%|██████████| 1000/1000 [00:27<00:00, 35.79it/s]

# %%
plt.imshow(sample4.to("cpu").numpy()[5, 0], cmap = "gray")
plt.show()

# %%
sample5 = score.sample(shape = [8, 1, 64, 64], steps = 4000)
# Out:
# Sampling from the prior | t = 0.0 | sigma = 1.0e-02| scale ~ 5.1e-01: 100%|██████████| 4000/4000 [01:51<00:00, 35.78it/s]

# %%
plt.imshow(sample5.to("cpu").numpy()[5, 0], cmap = "gray")
plt.show()

# %%
sample6 = score.sample(shape = [8, 1, 64, 64], steps = 4000)
# Out:
# Sampling from the prior | t = 0.0 | sigma = 1.0e-02| scale ~ 5.3e-01: 100%|██████████| 4000/4000 [01:51<00:00, 35.80it/s]

# %%
plt.imshow(sample6.to("cpu").numpy()[6, 0], cmap = "gray")
plt.show()

# %%
costs = [9.2e+02,
6.3e+02,
6.1e+02,
6.1e+02,
6.0e+02,
6.0e+02,
6.0e+02,
5.9e+02,
5.9e+02,
5.9e+02,
5.8e+02,
5.8e+02,
5.8e+02,
5.8e+02,
5.7e+02,
5.7e+02,
5.7e+02,
5.7e+02,
5.8e+02,
5.8e+02,
5.8e+02,
5.8e+02,
5.8e+02,
5.8e+02,
5.7e+02,
5.7e+02,
5.7e+02,
5.7e+02,
5.6e+02,
5.6e+02,
5.7e+02,
5.7e+02,
5.8e+02,
5.5e+02,
5.7e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.5e+02,
5.7e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.5e+02,
5.5e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.5e+02,
5.5e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.6e+02,
5.5e+02]
plt.plot(costs)
